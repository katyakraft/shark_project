# %%
#!pip install --upgrade xlrd

# %%
import pandas as pd
import numpy as np
from Shark_functions import shark_categories, generalize_injury

df = pd.read_excel(r"C:\Users\benja\Downloads\GSAF5.xls")


df
# Out:
#              Date    Year        Type    Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
# ...           ...     ...         ...        ...                ...
# 6964          NaN     NaN         NaN        NaN                NaN
# 6965          NaN     NaN         NaN        NaN                NaN
# 6966          NaN     NaN         NaN        NaN                NaN
# 6967          NaN     NaN         NaN        NaN                NaN
# 6968          NaN     NaN         NaN        NaN                NaN
#
#                               Location  Activity                 Name  Sex  \
# ...

# %%
#when it happened / provoked ? / location / activity / details of the persons / Injury / Survived? / species of sharks / source of news

# %%
df.rename(columns={'Species ': 'Species'}, inplace=True)

# %%
df.rename(columns={'Unnamed: 11': 'deceased'}, inplace=True)

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.head()
# Out:
#           date    year        type    country              state  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1  04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2  02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3  25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4  14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
#
#                            location  activity                 name sex  age  \
# 0                     Bargara Beach  Swimming       Brooklyn Sauer   F   13
# 1                Old Man's, Waikiki   Surfing        Matthew White   M  NaN
# 2                    Rainbows, Oahu  Swimming                  NaN   F   11
# 3        Sandlnd Island, Jurian Bay       NaN               female   F   46
# 4  Vaitarna River, Palghar District   Fishing  Vicky Suresh Govari   M   32
#
#    ...         species                     source  pdf href_formula href  \
# ...

# %%
#we are an American company (Miami); New Smyrna Beach, where many shark reports happen. 
#We propose daily shark activity, where you can see sharks in their natural environment

#we propose "secure" package with low risk you still have a greatful day
#we propose high risk activities with sharks to enhance your adrealine (sign disclosure and insurance before hand)

#One Direction, we go straight forward to your satisfaction

# %%
df.isna().sum()
# Out:
# date                25
# year                27
# type                43
# country             75
# state              507
# location           590
# activity           611
# name               245
# sex                604
# age               3019
# injury              60
# deceased           587
# time              3551
# species           3157
# source              44
# pdf                170
# href_formula       150
# href               173
# case_number        171
# case_number.1      172
# original_order     170
# unnamed:_21       6968
# unnamed:_22       6967
# dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# USA                   2538
# AUSTRALIA             1481
# SOUTH AFRICA           597
# NEW ZEALAND            144
# BAHAMAS                136
#                       ...
# PUERTO RICO              1
# RED SEA                  1
# Coral Sea                1
# BRITISH ISLES            1
# CEYLON (SRI LANKA)       1
# Name: count, Length: 225, dtype: int64

# %%
df["state"].value_counts()
# Out:
# state
# Florida                1178
# New South Wales         521
# Queensland              347
# Hawaii                  341
# California              323
#                        ...
# Shizuoka Prefecture       1
# Brindisi Province         1
# Kagawa Prefecture         1
#  Upolu Island             1
# Moala Island              1
# Name: count, Length: 902, dtype: int64

# %%
df[["state", "location"]].value_counts()
# Out:
# state            location
# Florida          New Smyrna Beach, Volusia County              191
#                  Daytona Beach, Volusia County                  31
#                  Ponce Inlet, Volusia County                    28
# South Carolina   Myrtle Beach, Horry County                     22
# Florida          Melbourne Beach, Brevard County                20
#                                                               ...
# Hawaii           Olowalu                                         1
#                  Olowalu side of Lahina, Maui                    1
#                  One'ula Beach Park, 'Ewa Beach, O'ahu           1
#                  Opposite Grand Wailea Resort, Wailea, Maui      1
# New South Wales  Arakoon's Little Bay                            1
# Name: count, Length: 4384, dtype: int64

# %%
nan_location_df =  df.dropna(subset = ["country", "state", "location"], thresh = 3)
nan_location_df
# Out:
#              date    year        type             country              state  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6934   Circa 1862     0.0  Unprovoked                 USA             Hawaii
# 6938  Before 1906     0.0  Unprovoked           AUSTRALIA    New South Wales
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
#Percentage of nan_location_df
a = 6143/6969*100
a
# Out:
# 88.14751040321424

# %%
#Calculating a threshold we want to apply (based on Nan from name) and check the percentage of Nan we could roughly remove
b = 245/6969*100
b
# Out:
# 3.515568948199168

# %%
lownan_df =  df.dropna(subset = ["date", "year", "type", "country", "name", "injury", "source"], thresh = 7)
lownan_df
# Out:
#              date    year        type             country              state  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# 5     04-Feb-2024  2024.0    Provoked            TRINIDAD                NaN
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
lownan_df.isna().sum()
# Out:
# date                 0
# year                 0
# type                 0
# country              0
# state              399
# location           477
# activity           496
# name                 0
# sex                416
# age               2712
# injury               0
# deceased           486
# time              3255
# species           2945
# source               0
# pdf                142
# href_formula       147
# href               145
# case_number        143
# case_number.1      144
# original_order     143
# unnamed:_21       6615
# unnamed:_22       6614
# dtype: int64

# %%
#We went even further in the threshold
lownan_df_v2 =  df.dropna(subset = ["date", "year", "type", "country", "name", "injury", "source", "pdf", "href_formula", "href", "case_number", "case_number.1", "original_order"], thresh = 13)
lownan_df_v2
# Out:
#              date    year        type             country  \
# 138   25-Sep-2022  2022.0  Unprovoked        SOUTH AFRICA
# 140   06-Sep-2022  2022.0  Unprovoked             BAHAMAS
# 141   03-Sep-2022  2022.0  Unprovoked                 USA
# 142   31-Aug-2022  2022.0  Unprovoked           AUSTRALIA
# 143   17-Aug-2022  2022.0  Unprovoked           AUSTRALIA
# ...           ...     ...         ...                 ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6941    1900-1905     0.0  Unprovoked                 USA
# 6942    1883-1889     0.0  Unprovoked              PANAMA
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                       state                             location  \
# 138   Western Cape Province       Central Beach, Plettenberg Bay
# 140                     NaN                            Green Cay
# 141                  Hawaii          Lower Paia Beach Park, Maui
# ...

# %%
lownan_df_v2.isna().sum()
# Out:
# date                 0
# year                 0
# type                 0
# country              0
# state              393
# location           470
# activity           492
# name                 0
# sex                414
# age               2684
# injury               0
# deceased           480
# time              3216
# species           2873
# source               0
# pdf                  0
# href_formula         0
# href                 0
# case_number          0
# case_number.1        0
# original_order       0
# unnamed:_21       6467
# unnamed:_22       6466
# dtype: int64

# %%
#Percentage of rows remaining after cleaning with threshold
c = 6468/6969*100
c
# Out:
# 92.81102023245803

# %%
lownan_df_v2 = df[(df['state'] == "Florida") & (df['location'] == "New Smyrna Beach, Volusia County")]
lownan_df_v2
# Out:
#              date    year          type country    state  \
# 40    12 Sep-2023  2023.0  Questionable     USA  Florida
# 54    31 Jul-2023  2023.0    Unprovoked     USA  Florida
# 159   10-Jul-2022  2022.0    Unprovoked     USA  Florida
# 162   03-Jul-2022  2022.0    Unprovoked     USA  Florida
# 197   13-Mar-2022  2022.0    Unprovoked     USA  Florida
# ...           ...     ...           ...     ...      ...
# 3889  20-Jun-1974  1974.0    Unprovoked     USA  Florida
# 3946  14-Oct-1972  1972.0    Unprovoked     USA  Florida
# 4050  02-Aug-1969  1969.0    Unprovoked     USA  Florida
# 4371  15-Jul-1963  1963.0    Unprovoked     USA  Florida
# 4440  17-Jun-1962  1962.0    Unprovoked     USA  Florida
#
#                               location         activity              name sex  \
# 40    New Smyrna Beach, Volusia County          Surfing   Mark Summersett   M
# 54    New Smyrna Beach, Volusia County          Surfing   Brandon Boncore   M
# ...

# %%
df["country"].value_counts().head(10)
# Out:
# country
# USA                 2538
# AUSTRALIA           1481
# SOUTH AFRICA         597
# NEW ZEALAND          144
# BAHAMAS              136
# PAPUA NEW GUINEA     136
# BRAZIL               122
# MEXICO               103
# ITALY                 72
# FIJI                  67
# Name: count, dtype: int64

# %%
df["state"].value_counts().head(10)
# Out:
# state
# Florida                  1178
# New South Wales           521
# Queensland                347
# Hawaii                    341
# California                323
# Western Australia         231
# KwaZulu-Natal             218
# Western Cape Province     197
# South Carolina            172
# Eastern Cape Province     168
# Name: count, dtype: int64

# %%
#Filter rows where the state is 'Florida'
florida_df = lownan_df_v2[lownan_df_v2["state"] == "Florida"]

#Count of null values for 'Florida'
null_values_florida = florida_df.isna().sum()
null_values_florida
# Out:
# date                0
# year                0
# type                0
# country             0
# state               0
# location            0
# activity            5
# name                0
# sex                 3
# age                 8
# injury              0
# deceased            3
# time               15
# species           107
# source              0
# pdf                 2
# href_formula        2
# href                2
# case_number         2
# case_number.1       2
# original_order      2
# unnamed:_21       191
# unnamed:_22       191
# dtype: int64

# %%
#List of all US states

us_states = [
    'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida',
    'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine',
    'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
    'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
    'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
    'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'
]

# %%
us_states_df = df[df['state'].isin(us_states)]

print(us_states_df["state"].value_counts().head(30))
# Out:
# state
# Florida           1178
# Hawaii             341
# California         323
# South Carolina     172
# North Carolina     118
# Texas               78
# New Jersey          56
# New York            45
# Oregon              31
# Virginia            19
# Louisiana           18
# Massachusetts       18
# Alabama             17
# Georgia             17
# Maryland            10
# Mississippi          8
# Delaware             8
# Rhode Island         8
# Connecticut          6
# Washington           2
# Maine                2
# Kentucky             1
# New Mexico           1
# Alaska               1
# Missouri             1
# Pennsylvania         1
# Illinois             1
# Name: count, dtype: int64

# %%
lownan_df_v2.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'state', 'location', 'activity',
#        'name', 'sex', 'age', 'injury', 'deceased', 'time', 'species', 'source',
#        'pdf', 'href_formula', 'href', 'case_number', 'case_number.1',
#        'original_order', 'unnamed:_21', 'unnamed:_22'],
#       dtype='object')

# %%
#Working on the diferent injuries recorded on Smyrna beach, Florida
lownan_df_v2["injury"].value_counts()
# Out:
# injury
# Foot bitten                           8
# Lacerations to foot                   5
# Minor injury to left foot             4
# Minor injury to foot                  4
# Right foot bitten                     4
#                                      ..
# Minor puncture wounds                 1
# No injury, shark charged surfboard    1
# Lacerations to right  hand            1
# Left thigh bitten                     1
# 8" laceration on left calf            1
# Name: count, Length: 156, dtype: int64

# %%
#The different injuries recorded
lownan_df_v2["injury"].unique()
# Out:
# array(['Llacerations to face and chin', 'Ankle injured',
#        'Minor injury to foot', 'Foot bitten', 'Bite to right foot',
#        'Minor injuries to knee and calf of left leg                            PROVOKED INCIDENT                 ',
#        'Minor cuts to right foot and ankle', 'Leg bitten',
#        'Right calf bitten', 'Minor injury to right foot',
#        'Minor lacerations to left leg', 'Lacerations to foot ',
#        'Left foot bitten ',
#        'Left foot bitten when he jumped on the shark  PROVOKED INCIDENT',
#        'No injury, knocked from his board by the shark',
#        'Minor cuts when he jumped off his board and landed on the shark. PROVOKED INCIDENT',
#        'Hand and calf bitten when he jumped off surfboard and landed on the shark PROVOKED INCIDENT',
#        'Puncture marks to lower leg', 'Minor injuries to right foot',
#        'Minor cuts to right foot', 'Bite to left hand and wrist',
# ...

# %%
# Lists of common body parts

#leg_parts = ['leg', 'knee', 'calf', 'thigh']
#foot_parts = ['foot', 'ankle', 'toe', 'heel']

#hand_parts = ['hand', 'finger', 'wrist']
#arm_parts = ['arm', 'forearm', 'elbow']

#torso_back_parts = ['torso', 'back']

#head_parts = ['head', 'chin', 'face']

# %%
#Function to group the different injuries into body part categories

import re

#Function to generalize injuries       

# Apply the function to the 'injury' column
lownan_df_v2['generalized_injury'] = lownan_df_v2['injury'].apply(generalize_injury)
lownan_df_v2[['injury', 'generalized_injury']]
# Out:
# C:\Users\benja\AppData\Local\Temp\ipykernel_42920\48069796.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lownan_df_v2['generalized_injury'] = lownan_df_v2['injury'].apply(generalize_injury)
#                                           injury    generalized_injury
# 40                 Llacerations to face and chin  torso or head injury
# 54                                 Ankle injured           foot injury
# 159                         Minor injury to foot           foot injury
# 162                                  Foot bitten           foot injury
# 197                           Bite to right foot           foot injury
# ...                                          ...                   ...
# ...

# %%
#Value counts of the generalized_injury

injury_counts = lownan_df_v2['generalized_injury'].value_counts()
injury_counts
# Out:
# generalized_injury
# foot injury             111
# leg injury               46
# hand injury              20
# Unknown injury            6
# arm injury                6
# torso or head injury      2
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Pie chart of those generalized_injury

injury_counts = lownan_df_v2['generalized_injury'].value_counts()
plt.figure(figsize=(6, 6))
injury_counts.plot(kind='pie', autopct='%1.1f%%', colors=plt.get_cmap('Set2').colors)
plt.title('Injuries')
plt.ylabel('')
plt.show()

# %%
sex_distribution = lownan_df_v2['sex'].value_counts()
sex_distribution.index = sex_distribution.index.map({'M': 'Male', 'F': 'Female'})
plt.figure(figsize=(6, 6))
sex_distribution.plot(kind='pie', autopct='%1.1f%%', colors=plt.get_cmap('Set2').colors)
plt.title('Distribution of Sex')
plt.ylabel('')
plt.show()

# %%
#conda --version python

# %%
#conda install --upgrade matplotlib

# %%
#Now working on the species of sharks present in Smyrna Beach

lownan_df_v2["species"].value_counts()
# Out:
# species
# 4' to 5' shark                                        9
# 3' shark                                              6
# Possibly a juvenile blacktip or spinner shark         5
# 4' shark                                              5
# 6' shark                                              3
# 5' shark                                              3
# blacktip or spinner shark                             3
# 3' to 4' shark                                        3
# 3.5' to 4' shark                                      3
# Blacktip shark                                        3
# juvenile shark                                        2
# Unidentified species                                  2
# 1.2 m [4'] shark                                      2
# Shark involvement not confirmed                       2
#                                                       2
# A 2' shark was seen in the area by witnesses          1
# 3' shark, possibly  a blacktip or spinner shark       1
# ...

# %%
lownan_df_v2["species"].unique()
# Out:
# array([nan, "6' shark", "Blacktip shark, 5' to 6'",
#        'Juvenile blacktip shark', "4' to 5' shark", "6.5' shark",
#        'Shark involvement not confirmed', "Bull shark, 6'",
#        'Blacktip shark', "Blacktip shark, 4' to 5'", 'juvenile shark',
#        "5' shark", 'Spinner shark', "3' shark", 'Bull shark',
#        "3.5' to 4' shark",
#        "6' shark, possibly a blactip or spinner shark", "3' to 4' shark",
#        "1' to 2' shark", "4' shark", 'blacktip or spinner shark', ' ',
#        "3' to 3.5' shark",
#        "Possibly a 1' to 3' blacktip or spinner shark", "2' to 3' shark",
#        'Unidentified species', 'Blacktip or spinner shark',
#        "3.5' to 4.5' shark", "0.9 m  to 1.2 m [3' to 4'] shark",
#        "3'  shark", "Spinner shark, 3' to 4' ",
#        'Possibly  a blacktip or spinner shark',
#        "3' shark, possibly  a blacktip or spinner shark",
#        "Blacktip shark, 5' to 6' ",
#        'Possibly a juvenile blacktip or spinner shark',
# ...

# %%
#Function to group the different shark species into shark size categories

import re
import pandas as pd

# Define a function to categorize shark sizes


# Apply the function to the 'species' column
lownan_df_v2['shark_categories'] = lownan_df_v2['species'].apply(shark_categories)

# Display the updated DataFrame with shark categories
print(lownan_df_v2[['species', 'shark_categories']])
# Out:
#                species    shark_categories
# 40                 NaN  Unidentified shark
# 54                 NaN  Unidentified shark
# 159           6' shark          shark > 2m
# 162                NaN  Unidentified shark
# 197                NaN  Unidentified shark
# ...                ...                 ...
# 3889               NaN  Unidentified shark
# 3946               NaN  Unidentified shark
# 4050               NaN  Unidentified shark
# 4371               NaN  Unidentified shark
# 4440  1.8 m [6'] shark          shark < 1m
#
# [191 rows x 2 columns]
# C:\Users\benja\AppData\Local\Temp\ipykernel_42920\1789668576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#count of shark size categories
shark_category = lownan_df_v2['shark_categories'].value_counts()
shark_category
# Out:
# shark_categories
# Unidentified shark    116
# shark < 1m             38
# 1m < shark < 2m        32
# shark > 2m              5
# Name: count, dtype: int64

# %%
#Percentage of available data
shark_total_id = 38 + 32 + 5
shark_total_id
# Out:
# 75

# %%
#Percentage of the different size of shark encountered
small_shark = 38 / 75 * 100
medium_shark = 32 / 75 * 100
large_shark = 5 / 75 * 100

print(f"You have {small_shark} chance to be attacked by a small shark")
print(f"You have {medium_shark} chance to be attacked by a medium shark")
print(f"You have {large_shark} chance to be attacked by a large shark")
# Out:
# You have 50.66666666666667 chance to be attacked by a small shark
# You have 42.66666666666667 chance to be attacked by a medium shark
# You have 6.666666666666667 chance to be attacked by a large shark

# %%
#Pie chart of our shark size distribution, including unidentified

import matplotlib.pyplot as plt

# Data for the pie chart
shark_sizes = ['Unidentified shark', 'shark < 1m', '1m < shark < 2m', 'shark > 2m']
shark_counts = [116, 38, 32, 5]

# Creating the pie chart
plt.figure(figsize=(6, 6))
plt.pie(shark_counts, labels=shark_sizes, autopct='%1.1f%%', colors=plt.get_cmap('Set2').colors)

# Adding title
plt.title('Shark Size Distribution')

# Display the pie chart
plt.show()

# %%
#Pie chart of our shark size distribution, excluding unidentified

import matplotlib.pyplot as plt

# Data for the pie chart
shark_sizes = ['shark < 1m', '1m < shark < 2m', 'shark > 2m']
shark_counts = [38, 32, 5]

# Creating the pie chart
plt.figure(figsize=(6, 6))
plt.pie(shark_counts, labels=shark_sizes, autopct='%1.1f%%', colors=plt.get_cmap('Set2').colors)

# Adding title
plt.title('Shark Size Distribution')

# Display the pie chart
plt.show()

# %%
#Focus on the activities while attacked by shark

lownan_df_v2.loc[df['activity'].str.contains('surf', case=False, na=False), 'activity'] = 'surfing'
print(lownan_df_v2.value_counts())
# Out:
# Series([], Name: count, dtype: int64)

# %%
lownan_df_v2.loc[df['activity'].str.contains('swim', case=False, na=False), 'activity'] = 'Swimming'
lownan_df_v2.loc[df['activity'].str.contains('wad', case=False, na=False), 'activity'] = 'Wading'
lownan_df_v2.loc[df['activity'].str.contains('board', case=False, na=False), 'activity'] = 'Boogie Boarding'
lownan_df_v2.loc[df['activity'].str.contains('raft', case=False, na=False), 'activity'] = 'Rafting'
lownan_df_v2.loc[df['activity'].str.contains('Others', case=False, na=False), 'activity'] = 'Fishing'
lownan_df_v2.loc[df['activity'].str.contains('Bathing', case=False, na=False), 'activity'] = 'Fishing'
lownan_df_v2.loc[df['activity'].str.contains('play', case=False, na=False), 'activity'] = 'Fishing'
print(lownan_df_v2.value_counts())
# Out:
# Series([], Name: count, dtype: int64)

# %%
#BAr graph of shark attacks age / activities

lownan_df_v2['age'] = pd.to_numeric(lownan_df_v2['age'], errors='coerce')

plt.figure(figsize=(12, 6))
sns.boxplot(x='activity', y='age', data=lownan_df_v2)
plt.xticks(rotation=45)
plt.xlabel('activity')
plt.ylabel('age')
plt.title('Shark attacks')
plt.grid(True)
plt.show()
# Out:
# C:\Users\benja\AppData\Local\Temp\ipykernel_42920\910682374.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lownan_df_v2['age'] = pd.to_numeric(lownan_df_v2['age'], errors='coerce')

# %%
#Bar graph to show the top 10 countries by shark attacks

import matplotlib.pyplot as plt

# Data for the bar graph
countries = ['USA', 'AUSTRALIA', 'SOUTH AFRICA', 'NEW ZEALAND', 'BAHAMAS', 
             'PAPUA NEW GUINEA', 'BRAZIL', 'MEXICO', 'ITALY', 'FIJI']
incident_counts = [2538, 1481, 597, 144, 136, 136, 122, 103, 72, 67]

# Creating the bar graph
plt.figure(figsize=(10, 6))
plt.bar(countries, incident_counts, color='skyblue')

# Adding labels and title
plt.xlabel('Country')
plt.ylabel('Number of Incidents')
plt.title('Number of Incidents by Country')

# Displaying the graph
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Bar graph to show the top 10 countries by shark attacks (Highliting our focus)

import matplotlib.pyplot as plt

# Data for the bar graph
countries = ['USA', 'AUSTRALIA', 'SOUTH AFRICA', 'NEW ZEALAND', 'BAHAMAS', 
             'PAPUA NEW GUINEA', 'BRAZIL', 'MEXICO', 'ITALY', 'FIJI']
incident_counts = [2538, 1481, 597, 144, 136, 136, 122, 103, 72, 67]

# Setting a default color and then overriding one specific data point (e.g., 'USA')
colors = ['skyblue' if country != 'USA' else 'red' for country in countries]

# Creating the bar graph
plt.figure(figsize=(10, 6))
plt.bar(countries, incident_counts, color=colors)

# Adding labels and title
plt.xlabel('Country')
plt.ylabel('Number of Incidents')
plt.title('Recorded shark attacks')

# Displaying the graph
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Bar graph to show the top 10 states by shark attacks

import matplotlib.pyplot as plt

# Data for the bar graph
states = ['Florida', 'Hawaii', 'California', 'South Carolina', 'North Carolina', 
          'Texas', 'New Jersey', 'New York', 'Oregon', 'Virginia', 
          'Louisiana', 'Massachusetts', 'Alabama', 'Georgia', 'Maryland']
incident_counts = [1178, 341, 323, 172, 118, 78, 56, 45, 31, 19, 18, 18, 17, 17, 10]

# Creating the bar graph
plt.figure(figsize=(10, 6))
plt.bar(states, incident_counts, color='lightgreen')

# Adding labels and title
plt.xlabel('State')
plt.ylabel('Number of Incidents')
plt.title('Number of Incidents by State')

# Displaying the graph
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Bar graph to show the top 10 states by shark attacks (Highliting our focus)

import matplotlib.pyplot as plt

# Data for the bar graph
states = ['Florida', 'Hawaii', 'California', 'South Carolina', 'North Carolina', 
          'Texas', 'New Jersey', 'New York', 'Oregon', 'Virginia', 
          ]
incident_counts = [1178, 341, 323, 172, 118, 78, 56, 45, 31, 19]

# Setting default colors and highlighting 'Florida'
colors = ['red' if state == 'Florida' else 'lightgreen' for state in states]

# Creating the bar graph
plt.figure(figsize=(10, 6))
plt.bar(states, incident_counts, color=colors)

# Adding labels and title
plt.xlabel('State')
plt.ylabel('Number of Incidents')
plt.title('Recorded shark attacks')

# Displaying the graph
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'state', 'location', 'activity',
#        'name', 'sex', 'age', 'injury', 'deceased', 'time', 'species', 'source',
#        'pdf', 'href_formula', 'href', 'case_number', 'case_number.1',
#        'original_order', 'unnamed:_21', 'unnamed:_22'],
#       dtype='object')

# %%
#Focus on the period of shark attacks over the year
# Define the mappings for common descriptions
month_mapping = {
    'january': 1, 'jan': 1,
    'february': 2, 'feb': 2,
    'march': 3, 'mar': 3,
    'april': 4, 'apr': 4,
    'may': 5,
    'june': 6, 'jun': 6,
    'july': 7, 'jul': 7,
    'august': 8, 'aug': 8,
    'september': 9, 'sep': 9, 'sept': 9,
    'october': 10, 'oct': 10,
    'november': 11, 'nov': 11,
    'december': 12, 'dec': 12
}

# Seasons mapping
season_to_month = {
    'winter': 1,  # Jan for simplicity
    'spring': 3,  # March
    'summer': 6,  # June
    'fall': 9     # September
}
def extract_month_from_description(description):
    if pd.isna(description):
        return None
    
    # Ensure description is a string
    description = str(description).lower()
    print(f"Processing description: {description}")  # Debug output
    
    # Check for specific date formats like '15 Mar 2024'
    date_match = re.search(r'(\d{1,2})[\s\-\/](\w+)[\s\-\/](\d{4})', description)
    if date_match:
        day, month_str, year = date_match.groups()
        month_str = month_str.lower()
        
        # Map month string to month number
        if month_str in month_mapping:
            print(f"Found valid date: {day} {month_str} {year}, returning month {month_mapping[month_str]}")  # Debug output
            return month_mapping[month_str]
    
    # Check for month name or abbreviation
    for month_name, month_number in month_mapping.items():
        if month_name in description:
            print(f"Found month in description: {month_name}, returning month {month_number}")  # Debug output
            return month_number
    
    # Check for seasons (summer, winter, etc.)
    for season, month in season_to_month.items():
        if season in description:
            print(f"Found season in description: {season}, returning month {month}")  # Debug output
            return month
    
    # Handle descriptions like 'before May' or 'after June'
    if 'before' in description or 'prior to' in description:
        for month_name, month_number in month_mapping.items():
            if month_name in description:
                print(f"Found 'before' in description: {description}, returning month {month_number - 1}")  # Debug output
                return month_number - 1 if month_number > 1 else 12
    
    if 'after' in description:
        for month_name, month_number in month_mapping.items():
            if month_name in description:
                print(f"Found 'after' in description: {description}, returning month {month_number + 1}")  # Debug output
                return month_number + 1 if month_number < 12 else 1
    
    print(f"Unable to extract month from description: {description}, returning None")  # Debug output
    return None

# Apply the function to the 'Date' column
df['month'] = df['date'].apply(extract_month_from_description)

# Handle missing values (fill with the mode)
df['month'].fillna(df['month'].mode()[0], inplace=True)

# Check results
print(df[['date', 'month']].head())
# Out:
# Processing description: 15 mar 2024
# Found valid date: 15 mar 2024, returning month 3
# Processing description: 04 mar 2024
# Found valid date: 04 mar 2024, returning month 3
# Processing description: 02 mar-2024
# Found valid date: 02 mar 2024, returning month 3
# Processing description: 25 feb-2024
# Found valid date: 25 feb 2024, returning month 2
# Processing description: 14 feb-2024
# Found valid date: 14 feb 2024, returning month 2
# Processing description: 04-feb-2024
# Found valid date: 04 feb 2024, returning month 2
# Processing description: 29 jan-2024
# Found valid date: 29 jan 2024, returning month 1
# Processing description: 15 jan-2024
# Found valid date: 15 jan 2024, returning month 1
# Processing description: 09-jan-2024
# Found valid date: 09 jan 2024, returning month 1
# Processing description: 05-jan-2024
# Found valid date: 05 jan 2024, returning month 1
# Processing description: 30 dec-2023
# Found valid date: 30 dec 2023, returning month 12
# ...

# %%
# Filter rows where the month is still missing or the date looks non-standard
invalid_dates = df[df['month'].isna() | df['date'].str.contains(r'[a-zA-Z]', na=False)]
print(invalid_dates[['date', 'month']].head(20))  # Print some ambiguous dates
# Out:
#             date  month
# 0    15 Mar 2024    3.0
# 1    04 Mar 2024    3.0
# 2    02 Mar-2024    3.0
# 3    25 Feb-2024    2.0
# 4    14 Feb-2024    2.0
# 5    04-Feb-2024    2.0
# 6    29 Jan-2024    1.0
# 7    15 Jan-2024    1.0
# 8    09-Jan-2024    1.0
# 9    05-Jan-2024    1.0
# 10   30 Dec-2023   12.0
# 11   29 Dec-2023   12.0
# 12   28 Dec-2023   12.0
# 13   25 Dec-2023   12.0
# 14   24-Dec-2023   12.0
# 15   18 Dec-2023   12.0
# 16  14  Dec-2023   12.0
# 17  14  Dec-2023   12.0
# 18   08 Dec-2023   12.0
# 19   04 Dec-2023   12.0

# %%
# Count the number of entries by month
month_counts = df['month'].value_counts().sort_index()

# Print the total number of shark attacks per month
print(month_counts)
# Out:
# month
# 1.0      568
# 2.0      416
# 3.0      458
# 4.0      493
# 5.0      450
# 6.0      563
# 7.0     1306
# 8.0      667
# 9.0      611
# 10.0     499
# 11.0     449
# 12.0     489
# Name: count, dtype: int64

# %%
new_smyrna_attacks = df[df['location'] == 'New Smyrna Beach, Volusia County']

# Count the number of shark attacks per month in Florida
new_smyrna_month_counts = new_smyrna_attacks['month'].value_counts().sort_index()

new_smyrna_month_counts
# Out:
# month
# 3.0     10
# 4.0     28
# 5.0     13
# 6.0     13
# 7.0     31
# 8.0     42
# 9.0     33
# 10.0    15
# 11.0     5
# 12.0     1
# Name: count, dtype: int64

# %%
# Create a bar plot of shark attacks in Florida by month
plt.figure(figsize=(10, 6))
new_smyrna_month_counts.plot(kind='bar', color='lightcoral')

plt.title('Shark Attacks in Florida', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Number of Attacks', fontsize=12)
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=0)

plt.show()
